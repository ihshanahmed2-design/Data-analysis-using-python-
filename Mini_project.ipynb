# %% [markdown]
# <a href="https://colab.research.google.com/github/ihshanahmed2-design/Data-analysis-using-python-/blob/main/Mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([10,20,30,40])
print(arr)
# Out:
# [10 20 30 40]

# %%
import pandas as pd

data = {
        "Name" : ["Ihshan","Ravi","Siva"],
        "Sales": [500,1500,2500]
}
df = pd.DataFrame(data)
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
import pandas as pd

data = {
     'emp_nm' :['Ihshan','Siva'],
     'emp_sal':[300,500],
}
df = pd.DataFrame(data)
df.rename(columns={
    'emp_nm' : 'Employee Name',
    'emp_sal': 'Employee Salary'
    }, inplace = True)
print(df)
# Out:
#   Employee Name  Employee Salary
# 0        Ihshan              300
# 1          Siva              500

# %%
import pandas as pd

data = {
    "Region":["South","North","East","West","South","North"],
    "Products":["Laptop","Mobile","Tablet","Laptop","Mobile","Tablet"],
    "Sales":[6000,7000,8000,9000,10000,11000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#   Region Products  Sales
# 0  South   Laptop   6000
# 1  North   Mobile   7000
# 2   East   Tablet   8000
# 3   West   Laptop   9000
# 4  South   Mobile  10000
# 5  North   Tablet  11000

# %%
import matplotlib.pyplot as plt
months = ["Jan","Feb","Mar","Apr","May"]
sales = [10000,12000,15000,13000,18000]
plt.plot(months,sales)
plt.title("Monthly sales")
plt.xlabel("Months")
plt.ylabel("Sales Amount")
plt.show()

# %%
import matplotlib.pyplot as plt
students = ["A","B","C","D"]
marks = [89,98,75,95]
plt.bar(students,marks)
plt.title("Student Marks")
plt.xlable("Students")
plt.ylable("Marks")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_20509/2230990735.py in <cell line: 0>()
#       4 plt.bar(students,marks)
#       5 plt.title("Student Marks")
# ----> 6 plt.xlable("Students")
#       7 plt.ylable("Marks")
#       8 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
import matplotlib.pyplot as plt
products = ["Laptop","Mobile","Tablet"]
sales = [50,58,39]
plt.bar(products,
        sales,
        color=["red","blue","green"])
plt.title("Product Sales")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
lables = ["A","B","C","D"]
sizes = [15,30,45,10]

# Create pie chart
plt.pie(sizes, labels=lables,
        autopct='%1.1f%%')

# Title
plt.title("Pie Chart Example")

# Show chart
plt.show()
